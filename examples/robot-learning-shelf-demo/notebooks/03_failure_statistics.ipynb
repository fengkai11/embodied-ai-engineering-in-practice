# %% [markdown]
# # Chapter 18 Failure Statistics
#
# 读取 `reports/ch18_failure_analysis.json`，快速查看失败原因和补采计划。

# %%
import json
from pathlib import Path
report = json.loads(Path('../reports/ch18_failure_analysis.json').read_text(encoding='utf-8'))
report['failure_reason_distribution']

# %%
report['failure_category_distribution']

# %% [markdown]
# 下一步可以将失败分布画成柱状图，并与 policy_v2 评测结果对比。
